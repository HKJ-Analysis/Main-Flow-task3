# %% [markdown]
# # Task - 3: Create a bar chart and a line chart using Matplotlib to visualize data from a Pandas DataFrame. Customize the charts with labels, titles, and legends.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("householdtask3.csv")
data
# Out:
#     year  tot_hhs      own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 0   2008  1560859  1087580  574406      69.7         36.8     100.0  35.9
# 1   2008   185965    71256   39405      38.3         21.2      11.9  29.9
# 2   2008   312376   191470   48424      61.3         15.5      20.0  40.0
# 3   2008   312333   196203   84171      62.8         26.9      20.0  34.7
# 4   2008   312240   217657  141318      69.7         45.3      20.0  31.5
# ..   ...      ...      ...     ...       ...          ...       ...   ...
# 65  2020   352564   213893  119637      60.7         33.9      20.1  36.9
# 66  2020   350182   235256  141104      67.2         40.3      19.9  35.0
# 67  2020   351328   288779  187838      82.2         53.5      20.0  39.6
# 68  2020   329588   156459  107753      47.5         32.7      18.8  31.1
# 69  2020   388013   314154   38270      81.0          9.9      22.1  69.8
#
#     size  income  expenditure  eqv_income  eqv_exp
# ...

# %%
# Line Chart with year and own

plt.plot(data['year'])
plt.plot(data['own'])

# x and y co-ordinates labels.
plt.xlabel('Year')
plt.ylabel('Own')

# Title of Chart
plt.title('Line Chart')

# To Display chart on screen.
plt.show()

# %%
# Bar Chart with year and own.

plt.bar(data['year'],data['own'])

# x and y co-ordinates label.
plt.xlabel('Year')
plt.ylabel('Own')

# Title of Chart
plt.title('Bar Chart')

# To Display chart on screen
plt.show()

# %%
# Scatter chart with year and Own.

plt.scatter(data['year'],data['own'],color = 'red')

# x and y co-ordinates label.
plt.xlabel('Year')
plt.ylabel('Own')

# Titile of chart
plt.title('Scatter Chart')

# To Display chart on screen.
plt.show()

# %%
# Histogram chart with year and own.

plt.hist(data['income'],color='#005C78')

# Title of Chart
plt.title('Histogram Chart')

# To Display chart oon screen.
plt.show()
